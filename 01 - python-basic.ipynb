# %% [markdown]
# ![image.png](attachment:6b653baa-9d4b-468e-a55c-c41f8e490574.png)

# %% [markdown]
# # *Print hello world*

# %%
# print hello world
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# # Data type, variable and conversion type

# %%
input_data = input("Please input your age: ")
# Out:
# Please input your age:  10

# %%
type(input_data)
# Out:
# str

# %%
age = int(input_data)
print(age)
print(type(age))
# Out:
# 10
# <class 'int'>

# %% [markdown]
# # Operations

# %% [markdown]
# ## Arithmetic

# %%
1+1
# Out:
# 2

# %%
"1" + "1"
# Out:
# '11'

# %%
"1" + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 "1" + 1
#
# TypeError: can only concatenate str (not "int") to str

# %%
"1" + str(1)
# Out:
# '11'

# %% [markdown]
# ## More with String

# %%
text = "      Hello, this is my 2nd session in Data science       "
text.upper()
# Out:
# '      HELLO, THIS IS MY 2ND SESSION IN DATA SCIENCE       '

# %%
text.lower()
# Out:
# '      hello, this is my 2nd session in data science       '

# %%
text.strip()
# Out:
# 'Hello, this is my 2nd session in Data science'

# %%
text.split()
# Out:
# ['Hello,', 'this', 'is', 'my', '2nd', 'session', 'in', 'Data', 'science']

# %%
text.split(",")
# Out:
# ['      Hello', ' this is my 2nd session in Data science       ']

# %%
text.replace("Data science", "DS")
# Out:
# '      Hello, this is my 2nd session in DS       '

# %%
text = "0123456789"
text[5:7] # exclude index 7
# Out:
# '56'

# %%
text[:7] # until index 7, but exclue index 7
# Out:
# '0123456'

# %%
text[0]
# Out:
# '0'

# %%
print("hello"
